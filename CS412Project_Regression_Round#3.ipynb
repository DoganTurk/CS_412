# %% [markdown]
# #Like Count Regression Task

# %%
import numpy as np
import pandas as pd
import json
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder
from matplotlib import pyplot as plt
import seaborn as sns
from pprint import pprint

# %% [markdown]
# # Train Dataset Analysis

# %%
train_file_path = "/content/training-dataset.jsonl"

train_data = []
with open(train_file_path, "r", encoding="utf-8") as file:
    for line in file:
        try:
            json_object = json.loads(line.strip())
            train_data.append(json_object)
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON: {e}")

df = pd.DataFrame(train_data)

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df.head()
# Out:
#                                              profile  \
# 0  {'username': 'deparmedya', 'id': '3170700063',...
# 1  {'username': 'beyazyakaliyiz', 'id': '86344574...
# 2  {'username': 'kafesfirin', 'id': '266439571', ...
# 3  {'username': 'vimerang', 'id': '2367195567', '...
# 4  {'username': 'totalenergies_istasyonlari', 'id...
#
#                                                posts
# 0  [{'caption': 'Cumhuriyetimizin 100.yılı kutlu ...
# 1  [{'caption': 'Bu diyaloğun yaşanmadığı bir onl...
# 2  [{'caption': 'Bugün bir fincan köpüklü Türk ka...
# 3  [{'caption': 'Saygı ve özlemle🖤
#
# #atatürk #10k...
# 4  [{'caption': 'Başöğretmenimiz Gazi Mustafa Kem...

# %%
profile_df = pd.json_normalize(df['profile'])

# Merge profile fields with top-level fields (except 'profile' which we've flattened)
user_df = pd.concat([df.drop(columns=['profile']), profile_df], axis=1)

user_df.head()
# Out:
#                                                posts  \
# 0  [{'caption': 'Cumhuriyetimizin 100.yılı kutlu ...
# 1  [{'caption': 'Bu diyaloğun yaşanmadığı bir onl...
# 2  [{'caption': 'Bugün bir fincan köpüklü Türk ka...
# 3  [{'caption': 'Saygı ve özlemle🖤
#
# #atatürk #10k...
# 4  [{'caption': 'Başöğretmenimiz Gazi Mustafa Kem...
#
#                      username          id                    full_name  \
# 0                  deparmedya  3170700063                  Depar Medya
# 1              beyazyakaliyiz  8634457436           Selam Beyaz Yakalı
# 2                  kafesfirin   266439571                  KAFES FIRIN
# 3                    vimerang  2367195567                     Vimerang
# 4  totalenergies_istasyonlari  7066643793  TotalEnergies İstasyonları
#
#                                            biography   category_name  \
# 0           #mediaplanning #mediabuying #sosyalmedya  Local business
# 1        Beyaz yakalıların dünyasına hoşgeldiniz 😀😀😀   Personal blog
# 2  📍Söğütözü📍FTZ AVM\n🛒Ankara macro▲center v...           Brand
# 3       Dijital İletişim Yönetimi🎬info@vimerang.comq            None
# 4  TotalEnergies İstasyonları resmi Instagram hes...  Energy Company
#
#    post_count  follower_count  following_count  is_business_account  \
# 0         NaN            1167              192                 True
# 1         NaN            1265              665                 True
# 2         NaN           11997               17                 True
# 3         NaN            2321              454                 True
# 4         NaN           28025                4                 True
#
#    is_private  is_verified  highlight_reel_count  \
# 0       False        False                     6
# 1       False        False                     0
# 2       False        False                    15
# 3       False        False                    11
# 4       False        False                    10
#
#                                            bio_links  \
# 0  "[{'title': '', 'lynx_url': 'https://l.instagr...
# 1  "[{'title': '', 'lynx_url': 'https://l.instagr...
# 2  "[{'title': '', 'lynx_url': 'https://l.instagr...
# 3  "[{'title': '', 'lynx_url': 'https://l.instagr...
# 4  "[{'title': '', 'lynx_url': 'https://l.instagr...
#
#                                             entities ai_agent_type  \
# 0           #mediaplanning #mediabuying #sosyalmedya          None
# 1        Beyaz yakalıların dünyasına hoşgeldiniz 😀😀😀          None
# 2  📍Söğütözü📍FTZ AVM\n🛒Ankara macro▲center v...          None
# 3       Dijital İletişim Yönetimi🎬info@vimerang.comq          None
# 4  TotalEnergies İstasyonları resmi Instagram hes...          None
#
#   fb_profile_biolink restricted_by_viewer  country_block          eimu_id  \
# 0               None                 None          False  110133017051179
# 1               None                 None          False  109046377161056
# 2               None                 None          False  111783696881731
# 3               None                 None          False  107818887285254
# 4               None                 None          False  112204746839186
#
#                             external_url               fbid  has_clips  \
# 0             http://www.deparmedya.com/  17841403241896337       True
# 1  http://yinemipazartesi.wordpress.com/  17841408443109307      False
# 2             http://www.kafesfirin.com/  17841400227134163       True
# 3                   http://vimerang.com/  17841402267035899       True
# 4                 https://bit.ly/45XDUDr  17841407073803330       True
#
#    hide_like_and_view_counts  is_professional_account  is_supervision_enabled  \
# 0                      False                     True                   False
# 1                      False                     True                   False
# 2                      False                     True                   False
# 3                       True                     True                   False
# 4                      False                     True                   False
#
#    is_guardian_of_viewer  is_supervised_by_viewer  is_supervised_user  \
# 0                  False                    False               False
# 1                  False                    False               False
# 2                  False                    False               False
# 3                  False                    False               False
# 4                  False                    False               False
#
#    is_embeds_disabled  is_joined_recently  \
# 0               False               False
# 1               False               False
# 2               False               False
# 3               False               False
# 4               False               False
#
#                                business_address_json business_contact_method  \
# 0  "{\"city_name\": null, \"city_id\": null, \"la...                    CALL
# 1  "{\"city_name\": null, \"city_id\": null, \"la...                 UNKNOWN
# 2  "{\"city_name\": null, \"city_id\": null, \"la...                    CALL
# 3  "{\"city_name\": \"Istanbul, Turkey\", \"city_...                    CALL
# 4  "{\"city_name\": null, \"city_id\": null, \"la...                    CALL
#
#   business_email business_phone_number  business_category_name  \
# 0           None                  None                    None
# 1           None                  None                    None
# 2           None                  None                    None
# 3           None                  None  Creators & Celebrities
# 4           None                  None                    None
#
#   overall_category_name   category_enum  is_verified_by_mv4b  \
# 0                  None           LOCAL                False
# 1                  None   PERSONAL_BLOG                False
# 2                  None           BRAND                False
# 3                  None   VIDEO_CREATOR                False
# 4                  None  ENERGY_COMPANY                False
#
#    is_regulated_c18                                    profile_pic_url  \
# 0             False  https://instagram.fsaw2-3.fna.fbcdn.net/v/t51....
# 1             False  https://instagram.fist6-1.fna.fbcdn.net/v/t51....
# 2             False  https://instagram.fada1-13.fna.fbcdn.net/v/t51...
# 3             False  https://instagram.fist19-1.fna.fbcdn.net/v/t51...
# 4             False  https://instagram.fsaw2-1.fna.fbcdn.net/v/t51....
#
#    should_show_category  should_show_public_contacts  \
# 0                  True                         True
# 1                  True                         True
# 2                  True                         True
# 3                  True                         True
# 4                  True                         True
#
#    show_account_transparency_details  \
# 0                               True
# 1                               True
# 2                               True
# 3                               True
# 4                               True
#
#                               profile_picture_base64
# 0  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...

# %%
# 1. Explode the 'posts' list so each post is its own row
posts_exploded = df.explode('posts', ignore_index=True)

# 2. Flatten the 'posts' dictionary into columns
posts_exploded = pd.concat(
    [posts_exploded.drop(columns=['posts']),
     pd.json_normalize(posts_exploded['posts'])],
    axis=1
)

# 3. Flatten the 'profile' dictionary as well
profile_flat_exploded = pd.json_normalize(posts_exploded['profile'])

# 4. Merge the flattened profile columns, dropping the original 'profile' column
posts_exploded = pd.concat(
    [posts_exploded.drop(columns=['profile']), profile_flat_exploded],
    axis=1
)

# Check the DataFrame
posts_exploded.head()
# Out:
#                                              caption  comments_count  \
# 0          Cumhuriyetimizin 100.yılı kutlu olsun♾️🇹🇷             0.0
# 1  Oriflame Duologi Lansmanı #isveçtengelengüzell...             1.0
# 2                     #oriflameilesaçbakımdevrimi ✌️             0.0
# 3  ✌️#oriflameilesaçbakımdevrimi 07Agustos’23 ori...             1.0
# 4            07 Agustos’23 #oriflameturkiye #duoloji             0.0
#
#                   id  like_count media_type  \
# 0  17990918969458720         6.0      IMAGE
# 1  18219250732221045        22.0      VIDEO
# 2  18311380465102328        19.0      VIDEO
# 3  18089518138361507        19.0      VIDEO
# 4  18012743929758497        21.0      VIDEO
#
#                                            media_url            timestamp  \
# 0  https://scontent-sof1-2.cdninstagram.com/v/t51...  2023-10-29 09:12:30
# 1  https://scontent-sof1-2.cdninstagram.com/o1/v/...  2023-08-08 19:11:13
# 2  https://scontent-sof1-2.cdninstagram.com/o1/v/...  2023-08-07 21:40:54
# 3  https://scontent-sof1-2.cdninstagram.com/o1/v/...  2023-08-07 21:27:48
# 4  https://scontent-sof1-2.cdninstagram.com/o1/v/...  2023-08-07 21:12:06
#
#      username          id    full_name  \
# 0  deparmedya  3170700063  Depar Medya
# 1  deparmedya  3170700063  Depar Medya
# 2  deparmedya  3170700063  Depar Medya
# 3  deparmedya  3170700063  Depar Medya
# 4  deparmedya  3170700063  Depar Medya
#
#                                   biography   category_name  post_count  \
# 0  #mediaplanning #mediabuying #sosyalmedya  Local business         NaN
# 1  #mediaplanning #mediabuying #sosyalmedya  Local business         NaN
# 2  #mediaplanning #mediabuying #sosyalmedya  Local business         NaN
# 3  #mediaplanning #mediabuying #sosyalmedya  Local business         NaN
# 4  #mediaplanning #mediabuying #sosyalmedya  Local business         NaN
#
#    follower_count  following_count  is_business_account  is_private  \
# 0            1167              192                 True       False
# 1            1167              192                 True       False
# 2            1167              192                 True       False
# 3            1167              192                 True       False
# 4            1167              192                 True       False
#
#    is_verified  highlight_reel_count  \
# 0        False                     6
# 1        False                     6
# 2        False                     6
# 3        False                     6
# 4        False                     6
#
#                                            bio_links  \
# 0  "[{'title': '', 'lynx_url': 'https://l.instagr...
# 1  "[{'title': '', 'lynx_url': 'https://l.instagr...
# 2  "[{'title': '', 'lynx_url': 'https://l.instagr...
# 3  "[{'title': '', 'lynx_url': 'https://l.instagr...
# 4  "[{'title': '', 'lynx_url': 'https://l.instagr...
#
#                                    entities ai_agent_type fb_profile_biolink  \
# 0  #mediaplanning #mediabuying #sosyalmedya          None               None
# 1  #mediaplanning #mediabuying #sosyalmedya          None               None
# 2  #mediaplanning #mediabuying #sosyalmedya          None               None
# 3  #mediaplanning #mediabuying #sosyalmedya          None               None
# 4  #mediaplanning #mediabuying #sosyalmedya          None               None
#
#   restricted_by_viewer  country_block          eimu_id  \
# 0                 None          False  110133017051179
# 1                 None          False  110133017051179
# 2                 None          False  110133017051179
# 3                 None          False  110133017051179
# 4                 None          False  110133017051179
#
#                  external_url               fbid  has_clips  \
# 0  http://www.deparmedya.com/  17841403241896337       True
# 1  http://www.deparmedya.com/  17841403241896337       True
# 2  http://www.deparmedya.com/  17841403241896337       True
# 3  http://www.deparmedya.com/  17841403241896337       True
# 4  http://www.deparmedya.com/  17841403241896337       True
#
#    hide_like_and_view_counts  is_professional_account  is_supervision_enabled  \
# 0                      False                     True                   False
# 1                      False                     True                   False
# 2                      False                     True                   False
# 3                      False                     True                   False
# 4                      False                     True                   False
#
#    is_guardian_of_viewer  is_supervised_by_viewer  is_supervised_user  \
# 0                  False                    False               False
# 1                  False                    False               False
# 2                  False                    False               False
# 3                  False                    False               False
# 4                  False                    False               False
#
#    is_embeds_disabled  is_joined_recently  \
# 0               False               False
# 1               False               False
# 2               False               False
# 3               False               False
# 4               False               False
#
#                                business_address_json business_contact_method  \
# 0  "{\"city_name\": null, \"city_id\": null, \"la...                    CALL
# 1  "{\"city_name\": null, \"city_id\": null, \"la...                    CALL
# 2  "{\"city_name\": null, \"city_id\": null, \"la...                    CALL
# 3  "{\"city_name\": null, \"city_id\": null, \"la...                    CALL
# 4  "{\"city_name\": null, \"city_id\": null, \"la...                    CALL
#
#   business_email business_phone_number business_category_name  \
# 0           None                  None                   None
# 1           None                  None                   None
# 2           None                  None                   None
# 3           None                  None                   None
# 4           None                  None                   None
#
#   overall_category_name category_enum  is_verified_by_mv4b  is_regulated_c18  \
# 0                  None         LOCAL                False             False
# 1                  None         LOCAL                False             False
# 2                  None         LOCAL                False             False
# 3                  None         LOCAL                False             False
# 4                  None         LOCAL                False             False
#
#                                      profile_pic_url  should_show_category  \
# 0  https://instagram.fsaw2-3.fna.fbcdn.net/v/t51....                  True
# 1  https://instagram.fsaw2-3.fna.fbcdn.net/v/t51....                  True
# 2  https://instagram.fsaw2-3.fna.fbcdn.net/v/t51....                  True
# 3  https://instagram.fsaw2-3.fna.fbcdn.net/v/t51....                  True
# 4  https://instagram.fsaw2-3.fna.fbcdn.net/v/t51....                  True
#
#    should_show_public_contacts  show_account_transparency_details  \
# 0                         True                               True
# 1                         True                               True
# 2                         True                               True
# 3                         True                               True
# 4                         True                               True
#
#                               profile_picture_base64
# 0  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...

# %%
posts_exploded['caption_length'] = posts_exploded['caption'].fillna('').apply(len)

agg_dict = {
    'like_count': ['mean', 'sum'],
    'comments_count': ['mean', 'sum']
    # You could add caption_length aggregates if desired
}

aggregated_posts = posts_exploded.groupby('username', as_index=False).agg(agg_dict)

# Flatten multi-level columns from aggregation
aggregated_posts.columns = [
    '_'.join(col).rstrip('_') if isinstance(col, tuple) else col
    for col in aggregated_posts.columns
]
# The result might be columns like:
#   profile.username, like_count_mean, like_count_sum, comments_count_mean, comments_count_sum

# Suppose these columns already exist in user_df
desired_profile_cols = [
    "username",
    "category_enum",
    "is_verified",
    "is_business_account",
    "follower_count",
    "following_count"
]

# 1. Slice user_df to keep only the columns we want.
#    (We include "username" for merging on that key.)
#    If you have duplicate rows for a user, you can also drop duplicates:
profile_subset_df = user_df[desired_profile_cols].drop_duplicates(subset=["username"])

# 2. Merge the desired profile columns into your aggregated_posts DataFrame
aggregated_posts = aggregated_posts.merge(
    profile_subset_df,
    on="username",   # Merge key
    how="left"       # Keep all rows in aggregated_posts even if some user info is missing
)

# 3. Check the columns in aggregated_post
aggregated_posts.head()
# Out:
#      username  like_count_mean  like_count_sum  comments_count_mean  \
# 0  01burdaavm        28.485714           997.0             1.200000
# 1   1001sanat        20.657143           723.0             0.485714
# 2  10burdaavm        36.714286          1285.0             0.171429
# 3  140journos     13391.571429        468705.0           135.657143
# 4      16roof        75.142857          2630.0             0.571429
#
#    comments_count_sum    category_enum  is_verified  is_business_account  \
# 0                42.0             None        False                 True
# 1                17.0  PERFORMING_ARTS        False                 True
# 2                 6.0             None        False                False
# 3              4748.0             None         True                False
# 4                20.0       RESTAURANT        False                 True
#
#    follower_count  following_count
# 0           34861               14
# 1           11146                7
# 2           35945              125
# 3          234739                0
# 4           38555                6

# %%
aggregated_posts.loc[aggregated_posts['username'] == 'kozayarismasi']
# Out:
#            username  like_count_mean  like_count_sum  comments_count_mean  \
# 2931  kozayarismasi       158.314286          5541.0             2.228571
#
#       comments_count_sum category_enum  is_verified  is_business_account  \
# 2931                78.0          None        False                False
#
#       follower_count  following_count
# 2931            8850              300

# %%
# Convert timestamp to datetime
posts_exploded['timestamp'] = pd.to_datetime(posts_exploded['timestamp'])

# Extract useful components
posts_exploded['post_hour'] = posts_exploded['timestamp'].dt.hour
posts_exploded['post_day_of_week'] = posts_exploded['timestamp'].dt.dayofweek  # 0 = Monday, 6 = Sunday
posts_exploded['post_month'] = posts_exploded['timestamp'].dt.month

# Calculate the total number of posts per user
post_counts = posts_exploded.groupby('username')['timestamp'].count().reset_index()
post_counts.columns = ['username', 'post_count']

# Calculate days since the first post and posting frequency
time_range = posts_exploded.groupby('username')['timestamp'].agg(['min', 'max']).reset_index()
time_range['days_active'] = (time_range['max'] - time_range['min']).dt.days + 1
time_range['posts_per_day'] = post_counts['post_count'] / time_range['days_active']

# Merge posting frequency back to aggregated_posts
aggregated_posts = aggregated_posts.merge(
    time_range[['username', 'posts_per_day', 'days_active']],
    on='username',
    how='left'
)

aggregated_posts.head()
# Out:
#      username  like_count_mean  like_count_sum  comments_count_mean  \
# 0  01burdaavm        28.485714           997.0             1.200000
# 1   1001sanat        20.657143           723.0             0.485714
# 2  10burdaavm        36.714286          1285.0             0.171429
# 3  140journos     13391.571429        468705.0           135.657143
# 4      16roof        75.142857          2630.0             0.571429
#
#    comments_count_sum    category_enum  is_verified  is_business_account  \
# 0                42.0             None        False                 True
# 1                17.0  PERFORMING_ARTS        False                 True
# 2                 6.0             None        False                False
# 3              4748.0             None         True                False
# 4                20.0       RESTAURANT        False                 True
#
#    follower_count  following_count  posts_per_day  days_active
# 0           34861               14       0.897436         39.0
# 1           11146                7       0.466667         75.0
# 2           35945              125       1.093750         32.0
# 3          234739                0       0.122378        286.0
# 4           38555                6       0.380435         92.0

# %%
from sklearn.preprocessing import LabelEncoder

# Copy the DataFrame to avoid modifying the original one
encoded_posts = aggregated_posts.copy()

# Label encode 'category_enum'
label_encoder = LabelEncoder()
encoded_posts['category_enum'] = label_encoder.fit_transform(encoded_posts['category_enum'].fillna('NONE'))

# Encode boolean columns as 0 and 1
bool_columns = ['is_verified', 'is_business_account']
for col in bool_columns:
    encoded_posts[col] = encoded_posts[col].astype(int)

aggregated_posts = encoded_posts

# Remove rows with NaN values from aggregated_posts
aggregated_posts.dropna(inplace=True)

aggregated_posts.head()
# Out:
#      username  like_count_mean  like_count_sum  comments_count_mean  \
# 0  01burdaavm        28.485714           997.0             1.200000
# 1   1001sanat        20.657143           723.0             0.485714
# 2  10burdaavm        36.714286          1285.0             0.171429
# 3  140journos     13391.571429        468705.0           135.657143
# 4      16roof        75.142857          2630.0             0.571429
#
#    comments_count_sum  category_enum  is_verified  is_business_account  \
# 0                42.0            238            0                    1
# 1                17.0            250            0                    1
# 2                 6.0            238            0                    0
# 3              4748.0            238            1                    0
# 4                20.0            292            0                    1
#
#    follower_count  following_count  posts_per_day  days_active
# 0           34861               14       0.897436         39.0
# 1           11146                7       0.466667         75.0
# 2           35945              125       1.093750         32.0
# 3          234739                0       0.122378        286.0
# 4           38555                6       0.380435         92.0

# %%
from sklearn.cluster import KMeans, DBSCAN
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# Add a minimal value to avoid log(0)
aggregated_posts['like_count_mean'] += 1e-5
aggregated_posts['comments_count_sum'] += 1e-5

# Apply log transformation to follower count, like count, and comment count
aggregated_posts['follower_count_log'] = np.log1p(aggregated_posts['follower_count'])
aggregated_posts['like_count_mean_log'] = np.log1p(aggregated_posts['like_count_mean'])
aggregated_posts['comments_count_sum_log'] = np.log1p(aggregated_posts['comments_count_sum'])

# Select log-transformed features for clustering
X_log = aggregated_posts[['follower_count_log', 'like_count_mean_log', 'comments_count_sum_log']]

# Scale the features to standardize the data
scaler = StandardScaler()
X_scaled_log = scaler.fit_transform(X_log)

# Apply DBSCAN clustering
dbscan = DBSCAN(eps=0.5, min_samples=10)  # Adjust eps and min_samples as needed
aggregated_posts['cluster'] = dbscan.fit_predict(X_scaled_log)

# Print the size of the dataset before outlier removal
print(f"Dataset size before outlier removal: {len(aggregated_posts)}")

# Remove outliers (noise points labeled as -1 by DBSCAN)
filtered_posts = aggregated_posts[aggregated_posts['cluster'] != -1].copy()

# Print the size of the dataset after outlier removal
print(f"Dataset size after outlier removal: {len(filtered_posts)}")

# Select features from the filtered dataset
X_filtered = filtered_posts[['follower_count_log', 'like_count_mean_log', 'comments_count_sum_log']]

# Apply KMeans clustering with 3 clusters on the outlier-free dataset
kmeans = KMeans(n_clusters=3, random_state=42)
filtered_posts['kmeans_cluster'] = kmeans.fit_predict(X_filtered)

# Define datasets explicitly for each cluster
cluster_0 = filtered_posts[filtered_posts['kmeans_cluster'] == 0]
cluster_1 = filtered_posts[filtered_posts['kmeans_cluster'] == 1]
cluster_2 = filtered_posts[filtered_posts['kmeans_cluster'] == 2]

cluster_0 = cluster_0.drop(columns=['cluster'])
cluster_1 = cluster_1.drop(columns=['cluster'])
cluster_2 = cluster_2.drop(columns=['cluster'])

# Print the sizes of each cluster
print(f"Cluster 0 Size: {len(cluster_0)}")
print(f"Cluster 1 Size: {len(cluster_1)}")
print(f"Cluster 2 Size: {len(cluster_2)}")

# Visualize the sizes of the new clusters
cluster_counts_kmeans = filtered_posts['kmeans_cluster'].value_counts()
print("KMeans Cluster Sizes (Outlier-Free Dataset):")
print(cluster_counts_kmeans)

# Visualize clusters without PCA (directly on follower count and like count)
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x=filtered_posts['follower_count_log'],
    y=filtered_posts['like_count_mean_log'],
    hue=filtered_posts['kmeans_cluster'],
    palette='viridis',
    s=70
)
plt.title('KMeans Clustering on Outlier-Free Dataset (Log-Transformed)')
plt.xlabel('Log Transformed Follower Count')
plt.ylabel('Log Transformed Average Like Count')
plt.legend(title='Cluster')
plt.show()

# Verify the first few rows of each cluster
print("\nCluster 0 - First 5 Rows:")
display(cluster_0.head())

print("\nCluster 1 - First 5 Rows:")
display(cluster_1.head())

print("\nCluster 2 - First 5 Rows:")
display(cluster_2.head())
# Out:
# Dataset size before outlier removal: 5391
# Dataset size after outlier removal: 5342
# Cluster 0 Size: 2264
# Cluster 1 Size: 2094
# Cluster 2 Size: 984
# KMeans Cluster Sizes (Outlier-Free Dataset):
# kmeans_cluster
# 0    2264
# 1    2094
# 2     984
# Name: count, dtype: int64
# Cluster 0 - First 5 Rows:
#       username  like_count_mean  like_count_sum  comments_count_mean  \
# 1    1001sanat        20.657153           723.0             0.485714
# 2   10burdaavm        36.714296          1285.0             0.171429
# 5      16tarim        19.914296           697.0             0.171429
# 8   1dil1insan        16.400010           574.0             0.657143
# 12  24saatteis        17.828581           624.0             0.200000
#
#     comments_count_sum  category_enum  is_verified  is_business_account  \
# 1             17.00001            250            0                    1
# 2              6.00001            238            0                    0
# 5              6.00001              8            0                    1
# 8             23.00001            124            0                    1
# 12             7.00001            238            0                    0
#
#     follower_count  following_count  posts_per_day  days_active  \
# 1            11146                7       0.466667         75.0
# 2            35945              125       1.093750         32.0
# 5             3079             1017       0.282258        124.0
# 8              526              151       0.081967        427.0
# 12           17483              699       0.393258         89.0
#
#     follower_count_log  like_count_mean_log  comments_count_sum_log  \
# 1             9.318926             3.075336                2.890372
# 2            10.489773             3.630039                1.945912
# 5             8.032685             3.040433                1.945912
# 8             6.267201             2.856471                3.178054
# 12            9.769041             2.935376                2.079443
#
#     kmeans_cluster
# 1                0
# 2                0
# 5                0
# 8                0
# 12               0
# Cluster 1 - First 5 Rows:
#          username  like_count_mean  like_count_sum  comments_count_mean  \
# 0      01burdaavm        28.485724           997.0             1.200000
# 4          16roof        75.142867          2630.0             0.571429
# 6    1924istanbul       571.742867         20011.0            13.457143
# 9   1kitap.1mekan       842.100010          8421.0            25.342857
# 10  1kizinonerisi       302.571439         10590.0             1.571429
#
#     comments_count_sum  category_enum  is_verified  is_business_account  \
# 0             42.00001            238            0                    1
# 4             20.00001            292            0                    1
# 6            471.00001            238            0                    1
# 9            887.00001             48            1                    1
# 10            55.00001            119            0                    1
#
#     follower_count  following_count  posts_per_day  days_active  \
# 0            34861               14       0.897436         39.0
# 4            38555                6       0.380435         92.0
# 6            31171              327       0.058725        596.0
# 9           142367             1359       0.416667         84.0
# 10           13837              691       0.144628        242.0
#
#     follower_count_log  like_count_mean_log  comments_count_sum_log  \
# 0            10.459153             3.383906                3.761200
# 4            10.559867             4.332611                3.044523
# 6            10.347276             6.350437                6.156979
# 9            11.866171             6.737086                6.788972
# 10            9.535174             5.715617                4.025352
#
#     kmeans_cluster
# 0                1
# 4                1
# 6                1
# 9                1
# 10               1
# Cluster 2 - First 5 Rows:
#        username  like_count_mean  like_count_sum  comments_count_mean  \
# 3    140journos     13391.571439        468705.0           135.657143
# 7   1983beyoglu      7450.257153        260759.0            26.457143
# 14    2daydance      5020.628581        175722.0            27.971429
# 38  ___daire___      3561.000010          3561.0            21.800000
# 40  _burakdeniz    256758.114296       8986534.0          2844.371429
#
#     comments_count_sum  category_enum  is_verified  is_business_account  \
# 3           4748.00001            238            1                    0
# 7            926.00001             89            0                    1
# 14           979.00001            238            0                    1
# 38           763.00001            136            0                    1
# 40         99553.00001            238            1                    0
#
#     follower_count  following_count  posts_per_day  days_active  \
# 3           234739                0       0.122378        286.0
# 7            18663               28       0.246479        142.0
# 14          147798             2318       0.466667         75.0
# 38          385757                3       0.853659         41.0
# 40         7135065              968       0.122378        286.0
#
#     follower_count_log  like_count_mean_log  comments_count_sum_log  \
# 3            12.366234             9.502455                8.465689
# 7             9.834352             8.916138                6.831954
# 14           11.903609             8.521510                6.887553
# 38           12.862966             8.178077                6.638568
# 40           15.780532            12.455894               11.508455
#
#     kmeans_cluster
# 3                2
# 7                2
# 14               2
# 38               2
# 40               2

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot boxplots for Cluster 0 (with outliers visible)
plt.figure(figsize=(10, 6))
sns.boxplot(
    data=cluster_0[['follower_count_log', 'like_count_mean_log', 'comments_count_sum_log']]
)
plt.title('Boxplot of Cluster 0 (Including Outliers)')
plt.ylabel('Values')
plt.xticks([0, 1, 2], ['Follower Count Log', 'Like Count Mean Log', 'Comments Count Sum Log'])
plt.show()

# Plot boxplots for Cluster 1 (with outliers visible)
plt.figure(figsize=(10, 6))
sns.boxplot(
    data=cluster_1[['follower_count_log', 'like_count_mean_log', 'comments_count_sum_log']]
)
plt.title('Boxplot of Cluster 1 (Including Outliers)')
plt.ylabel('Values')
plt.xticks([0, 1, 2], ['Follower Count Log', 'Like Count Mean Log', 'Comments Count Sum Log'])
plt.show()

# Plot boxplots for Cluster 2 (with outliers visible)
plt.figure(figsize=(10, 6))
sns.boxplot(
    data=cluster_2[['follower_count_log', 'like_count_mean_log', 'comments_count_sum_log']]
)
plt.title('Boxplot of Cluster 2 (Including Outliers)')
plt.ylabel('Values')
plt.xticks([0, 1, 2], ['Follower Count Log', 'Like Count Mean Log', 'Comments Count Sum Log'])
plt.show()

# %%
 # Calculate correlation matrix
temp_df = cluster_0.drop(columns=['username'])
correlation_matrix = temp_df.corr()

# Extract correlation with 'like_count_mean'
correlation_with_likes = correlation_matrix['like_count_mean_log'].sort_values(ascending=False)

# Visualize the correlation as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Feature Correlation Heatmap')
plt.show()

temp_df = cluster_1.drop(columns=['username'])
correlation_matrix = temp_df.corr()

# Extract correlation with 'like_count_mean'
correlation_with_likes = correlation_matrix['like_count_mean_log'].sort_values(ascending=False)

# Visualize the correlation as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Feature Correlation Heatmap')
plt.show()

temp_df = cluster_2.drop(columns=['username'])
correlation_matrix = temp_df.corr()

# Extract correlation with 'like_count_mean'
correlation_with_likes = correlation_matrix['like_count_mean_log'].sort_values(ascending=False)

# Visualize the correlation as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
def log_mse_like_counts(y_true, y_pred):
  """
  Calculate the Log Mean Squared Error (Log MSE) for like counts (log(like_count + 1)).

  Parameters:
  - y_true: array-like, actual like counts
  - y_pred: array-like, predicted like counts

  Returns:
  - log_mse: float, Log Mean Squared Error
  """
  # Ensure inputs are numpy arrays
  y_true = np.array(y_true)
  y_pred = np.array(y_pred)

  # Log transformation: log(like_count + 1)
  log_y_true = np.log1p(y_true)
  log_y_pred = np.log1p(y_pred)

  # Compute squared errors
  squared_errors = (log_y_true - log_y_pred) ** 2

  # Return the mean of squared errors
  return np.mean(squared_errors)

# %% [markdown]
# # Test Dataset Analysis

# %%
test_file_path = "/content/test-regression-round3.jsonl"

test_data = []
with open(test_file_path, "r", encoding="utf-8") as file:
    for line in file:
        try:
            json_object = json.loads(line.strip())
            test_data.append(json_object)
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON: {e}")

test_df = pd.DataFrame(test_data)
test_df.head()
# Out:
#                                              caption  comments_count  \
# 0  Ayvalık Belediyesi Kasım Ayı Olağan Meclis Top...              10
# 1  Olumsuz hava şartları sonucu ilçemizde ki sahi...              19
# 2  ❝Bizler ki aynı kitaba baş eğmiş insanlarız, b...              22
# 3                                                 ❤️             249
# 4  Değerlerimizin ışığında, dünyamıza iyi bakmak,...               0
#
#                   id      media_type  \
# 0  18299464882193238  CAROUSEL_ALBUM
# 1  17870639199008459           VIDEO
# 2  17976060503438195           IMAGE
# 3  17980348256173250  CAROUSEL_ALBUM
# 4  18030944311530609           IMAGE
#
#                                            media_url            timestamp  \
# 0  https://scontent-sof1-2.cdninstagram.com/v/t51...  2023-11-01 12:43:50
# 1                                               None  2023-11-20 11:17:14
# 2  https://scontent-sof1-1.cdninstagram.com/v/t39...  2023-11-13 13:02:57
# 3  https://scontent-sof1-1.cdninstagram.com/v/t51...  2023-07-31 10:31:17
# 4  https://scontent-sof1-1.cdninstagram.com/v/t51...  2023-07-13 13:36:38
#
#              username
# 0  mesuterginofficial
# 1    daricabelediyesi
# 2            fikriyat
# 3           obenalkan
# 4         kaledehayat

# %%
formatted_test_data = []

for i in test_df["username"]:
    if i in filtered_posts["username"].values:
        temp_row = filtered_posts.loc[filtered_posts["username"] == i]
        temp_row = temp_row.drop(columns=['like_count_mean_log'])

        temp_row['id'] = test_df.loc[test_df["username"] == i]['id'].values[0]
        temp_row['username'] = test_df.loc[test_df["username"] == i]['username'].values[0]
        formatted_test_data.append(temp_row)


formatted_test_df = pd.concat(formatted_test_data, ignore_index=True)
formatted_test_df["like_count_mean_log"] = 0  # Placeholder for prediction



test_cluster_0 = formatted_test_df.loc[formatted_test_df["kmeans_cluster"] == 0]
test_cluster_1 = formatted_test_df.loc[formatted_test_df["kmeans_cluster"] == 1]
test_cluster_2 = formatted_test_df.loc[formatted_test_df["kmeans_cluster"] == 2]

test_cluster_0 = test_cluster_0.drop(columns=['cluster', 'kmeans_cluster'])
test_cluster_1 = test_cluster_1.drop(columns=['cluster', 'kmeans_cluster'])
test_cluster_2 = test_cluster_2.drop(columns=['cluster', 'kmeans_cluster'])

# %% [markdown]
# # Train the Training Dataset

# %%
print(len(test_cluster_0), len(test_cluster_1), len(test_cluster_2))
# Out:
# 1237 1176 552

# %%
cluster_1.head()
# Out:
#          username  like_count_mean  like_count_sum  comments_count_mean  \
# 0      01burdaavm        28.485724           997.0             1.200000
# 4          16roof        75.142867          2630.0             0.571429
# 6    1924istanbul       571.742867         20011.0            13.457143
# 9   1kitap.1mekan       842.100010          8421.0            25.342857
# 10  1kizinonerisi       302.571439         10590.0             1.571429
#
#     comments_count_sum  category_enum  is_verified  is_business_account  \
# 0             42.00001            238            0                    1
# 4             20.00001            292            0                    1
# 6            471.00001            238            0                    1
# 9            887.00001             48            1                    1
# 10            55.00001            119            0                    1
#
#     follower_count  following_count  posts_per_day  days_active  \
# 0            34861               14       0.897436         39.0
# 4            38555                6       0.380435         92.0
# 6            31171              327       0.058725        596.0
# 9           142367             1359       0.416667         84.0
# 10           13837              691       0.144628        242.0
#
#     follower_count_log  like_count_mean_log  comments_count_sum_log  \
# 0            10.459153             3.383906                3.761200
# 4            10.559867             4.332611                3.044523
# 6            10.347276             6.350437                6.156979
# 9            11.866171             6.737086                6.788972
# 10            9.535174             5.715617                4.025352
#
#     kmeans_cluster
# 0                1
# 4                1
# 6                1
# 9                1
# 10               1

# %%
def log_mse_like_counts(y_true, y_pred):
    return np.sum((np.log1p(y_true) - np.log1p(y_pred)) ** 2) / len(y_true)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.metrics import mean_squared_error
import numpy as np

# Drop 'username' if necessary
cluster_0 = cluster_0.drop(columns=['username', 'kmeans_cluster'])
cluster_1 = cluster_1.drop(columns=['username', 'kmeans_cluster'])
cluster_2 = cluster_2.drop(columns=['username', 'kmeans_cluster'])

# Split Cluster 0 into train (70%), validation (15%), and test (15%)
X_0_features = cluster_0.drop(columns=['like_count_mean_log'])
y_0_target = cluster_0['like_count_mean_log']

X_0_train, X_0_temp, y_0_train, y_0_temp = train_test_split(
    X_0_features, y_0_target, test_size=0.3, random_state=42
)
X_0_val, X_0_test, y_0_val, y_0_test = train_test_split(
    X_0_temp, y_0_temp, test_size=0.5, random_state=42
)

# Split Cluster 1 into train (70%), validation (15%), and test (15%)
X_1_features = cluster_1.drop(columns=['like_count_mean_log'])
y_1_target = cluster_1['like_count_mean_log']

X_1_train, X_1_temp, y_1_train, y_1_temp = train_test_split(
    X_1_features, y_1_target, test_size=0.3, random_state=42
)
X_1_val, X_1_test, y_1_val, y_1_test = train_test_split(
    X_1_temp, y_1_temp, test_size=0.5, random_state=42
)

# Split Cluster 2 into train (70%), validation (15%), and test (15%)
X_2_features = cluster_2.drop(columns=['like_count_mean_log'])
y_2_target = cluster_2['like_count_mean_log']

X_2_train, X_2_temp, y_2_train, y_2_temp = train_test_split(
    X_2_features, y_2_target, test_size=0.3, random_state=42
)
X_2_val, X_2_test, y_2_val, y_2_test = train_test_split(
    X_2_temp, y_2_temp, test_size=0.5, random_state=42
)

# Initialize Random Forest models for all clusters
model_0 = RandomForestRegressor(n_estimators=150, max_depth=6, random_state=42)
model_1 = RandomForestRegressor(n_estimators=150, max_depth=6, random_state=42)
model_2 = RandomForestRegressor(n_estimators=150, max_depth=6, random_state=42)

# Perform 10-fold cross-validation for Cluster 0
kf = KFold(n_splits=10, shuffle=True, random_state=42)
cv_scores_0 = cross_val_score(model_0, X_0_train, y_0_train, cv=kf, scoring='neg_mean_squared_error')
cv_scores_1 = cross_val_score(model_1, X_1_train, y_1_train, cv=kf, scoring='neg_mean_squared_error')
cv_scores_2 = cross_val_score(model_2, X_2_train, y_2_train, cv=kf, scoring='neg_mean_squared_error')

print(f"Cluster 0 - Mean MSE (10-fold CV): {np.mean(np.abs(cv_scores_0))}")
print(f"Cluster 1 - Mean MSE (10-fold CV): {np.mean(np.abs(cv_scores_1))}")
print(f"Cluster 2 - Mean MSE (10-fold CV): {np.mean(np.abs(cv_scores_2))}")

# Train the models on the full training dataset
model_0.fit(X_0_train, y_0_train)
model_1.fit(X_1_train, y_1_train)
model_2.fit(X_2_train, y_2_train)

# Evaluate on training datasets
train_pred_0 = model_0.predict(X_0_train)
train_pred_1 = model_1.predict(X_1_train)
train_pred_2 = model_2.predict(X_2_train)

# Inverse log transform (exp) and set negative predictions to 0
train_pred_0 = np.maximum(np.expm1(train_pred_0), 0)
train_pred_1 = np.maximum(np.expm1(train_pred_1), 0)
train_pred_2 = np.maximum(np.expm1(train_pred_2), 0)
y_0_train_exp = np.expm1(y_0_train)
y_1_train_exp = np.expm1(y_1_train)
y_2_train_exp = np.expm1(y_2_train)

# Define custom log error calculation (sum of absolute log errors)
def log_error_like_counts(y_true, y_pred):
    return np.sum(np.abs(np.log1p(y_true) - np.log1p(y_pred)))

# Apply the custom error function
train_log_error_0 = log_error_like_counts(y_0_train_exp, train_pred_0)
train_log_error_1 = log_error_like_counts(y_1_train_exp, train_pred_1)
train_log_error_2 = log_error_like_counts(y_2_train_exp, train_pred_2)

# Evaluate on validation datasets
val_pred_0 = model_0.predict(X_0_val)
val_pred_1 = model_1.predict(X_1_val)
val_pred_2 = model_2.predict(X_2_val)

val_pred_0 = np.maximum(np.expm1(val_pred_0), 0)
val_pred_1 = np.maximum(np.expm1(val_pred_1), 0)
val_pred_2 = np.maximum(np.expm1(val_pred_2), 0)
y_0_val_exp = np.expm1(y_0_val)
y_1_val_exp = np.expm1(y_1_val)
y_2_val_exp = np.expm1(y_2_val)

val_log_error_0 = log_error_like_counts(y_0_val_exp, val_pred_0)
val_log_error_1 = log_error_like_counts(y_1_val_exp, val_pred_1)
val_log_error_2 = log_error_like_counts(y_2_val_exp, val_pred_2)

# Evaluate on test datasets
test_pred_0 = model_0.predict(X_0_test)
test_pred_1 = model_1.predict(X_1_test)
test_pred_2 = model_2.predict(X_2_test)

test_pred_0 = np.maximum(np.expm1(test_pred_0), 0)
test_pred_1 = np.maximum(np.expm1(test_pred_1), 0)
test_pred_2 = np.maximum(np.expm1(test_pred_2), 0)
y_0_test_exp = np.expm1(y_0_test)
y_1_test_exp = np.expm1(y_1_test)
y_2_test_exp = np.expm1(y_2_test)

test_log_error_0 = log_error_like_counts(y_0_test_exp, test_pred_0)
test_log_error_1 = log_error_like_counts(y_1_test_exp, test_pred_1)
test_log_error_2 = log_error_like_counts(y_2_test_exp, test_pred_2)

# Print train, validation, and test log errors
print(f"\nCluster 0 - Train Sum of Log Errors: {train_log_error_0}")
print(f"Cluster 0 - Validation Sum of Log Errors: {val_log_error_0}")
print(f"Cluster 0 - Test Sum of Log Errors: {test_log_error_0}")

print(f"\nCluster 1 - Train Sum of Log Errors: {train_log_error_1}")
print(f"Cluster 1 - Validation Sum of Log Errors: {val_log_error_1}")
print(f"Cluster 1 - Test Sum of Log Errors: {test_log_error_1}")

print(f"\nCluster 2 - Train Sum of Log Errors: {train_log_error_2}")
print(f"Cluster 2 - Validation Sum of Log Errors: {val_log_error_2}")
print(f"Cluster 2 - Test Sum of Log Errors: {test_log_error_2}")
# Out:
# Cluster 0 - Mean MSE (10-fold CV): 0.001652071858012637
# Cluster 1 - Mean MSE (10-fold CV): 0.0016926154667292164
# Cluster 2 - Mean MSE (10-fold CV): 0.002517658791320632
#
# Cluster 0 - Train Sum of Log Errors: 7.388004191142381
# Cluster 0 - Validation Sum of Log Errors: 2.3218229709682108
# Cluster 0 - Test Sum of Log Errors: 1.5960273004147612
#
# Cluster 1 - Train Sum of Log Errors: 8.401998336443832
# Cluster 1 - Validation Sum of Log Errors: 1.5493732097330755
# Cluster 1 - Test Sum of Log Errors: 2.1206661839878387
#
# Cluster 2 - Train Sum of Log Errors: 7.393005603715799
# Cluster 2 - Validation Sum of Log Errors: 2.299688570058958
# Cluster 2 - Test Sum of Log Errors: 2.656478282765553

# %% [markdown]
# # Test Data Prediction

# %%
# ====== Predict Test Data ======
test_cluster_0_names = test_cluster_0['username']
test_cluster_0_ids = test_cluster_0['id']
test_cluster_0 = test_cluster_0.drop(columns=['username', 'id', 'like_count_mean_log'])

test_cluster_1_names = test_cluster_1['username']
test_cluster_1_ids = test_cluster_1['id']
test_cluster_1 = test_cluster_1.drop(columns=['username', 'id', 'like_count_mean_log'])

test_cluster_2_names = test_cluster_2['username']
test_cluster_2_ids = test_cluster_2['id']
test_cluster_2 = test_cluster_2.drop(columns=['username', 'id', 'like_count_mean_log'])

predicted_likes_0 = model_0.predict(test_cluster_0)
predicted_likes_0 = np.maximum(predicted_likes_0, 0)  # Ensure no negative predictions
predicted_likes_0 = np.expm1(predicted_likes_0)  # Inverse log transformation

predicted_likes_1 = model_1.predict(test_cluster_1)
predicted_likes_1 = np.maximum(predicted_likes_1, 0)  # Ensure no negative predictions
predicted_likes_1 = np.expm1(predicted_likes_1)  # Inverse log transformation

predicted_likes_2 = model_2.predict(test_cluster_2)
predicted_likes_2 = np.maximum(predicted_likes_2, 0)  # Ensure no negative predictions
predicted_likes_2 = np.expm1(predicted_likes_2)  # Inverse log transformation

# ====== Save Predictions to JSON ======
output_dict = {}
output_path = "/content/prediction-regression-round3.json"

for i in range(len(test_cluster_0_ids)):
    output_dict[str(test_cluster_0_ids.iloc[i])] = int(predicted_likes_0[i])

for i in range(len(test_cluster_1_ids)):
    output_dict[str(test_cluster_1_ids.iloc[i])] = int(predicted_likes_1[i])

for i in range(len(test_cluster_2_ids)):
    output_dict[str(test_cluster_2_ids.iloc[i])] = int(predicted_likes_2[i])

with open(output_path, "w") as of:
    json.dump(output_dict, of, indent=4)

print(f"Predictions saved successfully to {output_path}!")
# Out:
# Predictions saved successfully to /content/prediction-regression-round3.json!

# %%
import json

# Paths
test_order_path = "/content/test-regression-round3.jsonl"
output_path = "/content/prediction-regression-round3.json"
sorted_output_path = "/content/prediction-regression-round3.json"

# Step 1: Read the test file and extract IDs (JSON Lines format)
test_ids = []
with open(test_order_path, "r") as test_file:
    for line in test_file:
        try:
            test_entry = json.loads(line.strip())  # Parse each JSON line
            if "id" in test_entry:  # Extract 'id' field
                test_ids.append(str(test_entry["id"]))
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON line: {e}")

# Step 2: Load the predictions
with open(output_path, "r") as pred_file:
    predictions = json.load(pred_file)

# Step 3: Sort the predictions by test file order and ignore missing IDs
sorted_predictions = {test_id: predictions[test_id] for test_id in test_ids if test_id in predictions}

# Step 4: Save the sorted predictions
with open(sorted_output_path, "w") as sorted_file:
    json.dump(sorted_predictions, sorted_file, indent=4)

print(f"Sorted predictions saved successfully to {sorted_output_path}!")
# Out:
# Sorted predictions saved successfully to /content/prediction-regression-round3.json!

# %%
cluster_0.head()
# Out:
#     like_count_mean  like_count_sum  comments_count_mean  comments_count_sum  \
# 1         20.657153           723.0             0.485714            17.00001
# 2         36.714296          1285.0             0.171429             6.00001
# 5         19.914296           697.0             0.171429             6.00001
# 8         16.400010           574.0             0.657143            23.00001
# 12        17.828581           624.0             0.200000             7.00001
#
#     category_enum  is_verified  is_business_account  follower_count  \
# 1             250            0                    1           11146
# 2             238            0                    0           35945
# 5               8            0                    1            3079
# 8             124            0                    1             526
# 12            238            0                    0           17483
#
#     following_count  posts_per_day  days_active  follower_count_log  \
# 1                 7       0.466667         75.0            9.318926
# 2               125       1.093750         32.0           10.489773
# 5              1017       0.282258        124.0            8.032685
# 8               151       0.081967        427.0            6.267201
# 12              699       0.393258         89.0            9.769041
#
#     like_count_mean_log  comments_count_sum_log
# 1              3.075336                2.890372
# 2              3.630039                1.945912
# 5              3.040433                1.945912
# 8              2.856471                3.178054
# 12             2.935376                2.079443

# %%
aggregated_posts.loc[aggregated_posts["username"] == "kozayarismasi"]
# Out:
#            username  like_count_mean  like_count_sum  comments_count_mean  \
# 2931  kozayarismasi       158.314296          5541.0             2.228571
#
#       comments_count_sum  category_enum  is_verified  is_business_account  \
# 2931            78.00001            238            0                    0
#
#       follower_count  following_count  posts_per_day  days_active  \
# 2931            8850              300       0.686275         51.0
#
#       follower_count_log  like_count_mean_log  comments_count_sum_log  cluster
# 2931            9.088286             5.070879                4.369448        0
